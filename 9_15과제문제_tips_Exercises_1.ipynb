# %% [markdown]
# <a href="https://colab.research.google.com/github/aaoiii/2023-2-ESAA/blob/main/9_15%EA%B3%BC%EC%A0%9C%EB%AC%B8%EC%A0%9C_tips_Exercises_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %%
data1=pd.read_csv('tips.csv')

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips=data1
tips
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
a=sns.histplot(x=tips['total_bill'])
a.set_title('total_bill histogram')
# Out:
# Text(0.5, 1.0, 'total_bill histogram')

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
b=plt.subplots()
b=sns.regplot(x=tips['total_bill'],y=tips['tip'],fit_reg=False)

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
sns.relplot(data=tips, x='total_bill',y='tip',size='size')

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
c=plt.subplots()
c=sns.boxplot(y='total_bill',x='day',data=tips)

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.scatterplot(x='tip',y='day',data=tips,hue='sex')
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
aa= plt.subplots()
aa=sns.boxplot(x=tips['time'],y=tips['total_bill'])

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
dinner1=tips[tips['time']=='Dinner']
lunch1=tips[tips['time']=='Lunch']

hist_dinner=plt.subplot(1,2,1)
hist_lunch=plt.subplot(1,2,2)

hist_dinner.hist(dinner1['tip'])
hist_lunch.hist(lunch1['tip'])
hist_dinner.set_title('histogram of dinner tip')
hist_lunch.set_title('histogram of lunch tip')
# Out:
# Text(0.5, 1.0, 'histogram of lunch tip')

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
plot12=plt.figure()
plot1=plot12.add_subplot(1,2,1)
plot2=plot12.add_subplot(1,2,2)

male1=tips[tips['sex']=='Male']
female1=tips[tips['sex']=='Female']

sns.scatterplot(ax=plot1,data=male1,x='total_bill',y='tip',hue='smoker')
sns.scatterplot(ax=plot2,data=female1,x='total_bill',y='tip',hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.

# %%
tips.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#male 과 female 각각 size 별로 다른 total_bill 과 tip 의 scatterplot

# %%
plot13=plt.figure()
plot1=plot13.add_subplot(1,2,1)
plot2=plot13.add_subplot(1,2,2)

male1=tips[tips['sex']=='Male']
female1=tips[tips['sex']=='Female']

sns.scatterplot(ax=plot1,data=male1,x='total_bill',y='tip',hue='size')
sns.scatterplot(ax=plot2,data=female1,x='total_bill',y='tip',hue='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
