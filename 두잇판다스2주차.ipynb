# %% [markdown]
# <a href="https://colab.research.google.com/github/aaoiii/2023-2-ESAA/blob/main/%EB%91%90%EC%9E%87%ED%8C%90%EB%8B%A4%EC%8A%A42%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **<데이터 시각화가 필요한 이유>**
#
# - 앤스콤 4분할 그래프
# - 데이터 그룹을 시각화하면 데이터 그룹이 서로 다른 패턴을 가지고 있음을 알 수 있음

# %%
#앤스콤 데이터 집합 불러오기-seaborn library

import seaborn as sns

anscombe=sns.load_dataset('anscombe')
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
#matplotlib 라이브러리로 그래프 그리기

# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
#anscombe 데이터 프레임의 dataset 열에서 데이터 값이 I인 것만 추출

dataset_1=anscombe[anscombe['dataset']=='I']

# %%
#선 그래프는 plot 메서드로 그릴 수 있다.

plt.plot(dataset_1['x'],dataset_1['y'])
# Out:
# <div id='da75ba39-ad1b-4f35-880d-bdaea7f79383'></div>

# %%
#점으로 그래프를 그리려면 o를 세번째 인자로 전달하면 된다

plt.plot(dataset_1['x'],dataset_1['y'],'o')

# %% [markdown]
# **<앤스콤 데이터 집합 모두 사용해 그래프 만들기>**
#
# - 앤스콤 데이터 집합은 4개의 데이터 그룹으로 구성되어 있으며 각 데이터 그룹의 파악하려면 시각화해야함
#
#
#
# <matplotlib 라이브러리로 그래프 그리기>
# - 전체 그래프가 위치할 틀 만든다
# - 그래프를 그려넣을 그래프 격자 만든다
# - 격자에 그래프를 하나씩 추가한다
# - 첫번째 행이 다 차면 두번째 행에 그래프를 그려 넣는다

# %%
dataset_2=anscombe[anscombe['dataset']=='II']
dataset_3=anscombe[anscombe['dataset']=='III']
dataset_4=anscombe[anscombe['dataset']=='IV']

# %%
#그래프 격자 위치할 틀 만들기

fig=plt.figure()

# add_subplot으로 그래프 격자 그리기
axes1=fig.add_subplot(2,2,1)
axes2=fig.add_subplot(2,2,2)
axes3=fig.add_subplot(2,2,3)
axes4=fig.add_subplot(2,2,4)
# Out:
# <div id='f6cd7c03-d3f5-45ba-96c6-c31c07192263'></div>

# %%
axes1.plot(dataset_1['x'],dataset_1['y'],'o')
axes2.plot(dataset_2['x'],dataset_2['y'],'o')
axes3.plot(dataset_3['x'],dataset_3['y'],'o')
axes4.plot(dataset_4['x'],dataset_4['y'],'o')

fig
# Out:
# <div id='b64c9110-1835-4926-96a1-edb474db9bab'></div>

# %%
#그래프 격자에 제목 추가 set_title
axes1.set_title('dataset_1')
axes2.set_title('dataset_2')
axes3.set_title('dataset_3')
axes4.set_title('dataset_4')

fig
# Out:
# <div id='d1038b2e-7322-43d0-add4-a76576714c28'></div>

# %%
#기본 틀(fig)에 제목 추가 suptitle

fig.suptitle('Anscombe Data')
fig
# Out:
# <div id='91c31f47-7aa8-4e08-a020-582b470e3544'></div>

# %%
#그래프의 레이아웃 조절 tight_layout
fig.tight_layout()
fig
# Out:
# <div id='f9808970-ccd5-4c04-b984-edd39c59d13b'></div>

# %% [markdown]
# **<matplotlib 라이브러리 자유자재로 사용하기>**
#
# - 기초그래프 그리기 - 히스토그램, 산점도, 박스그래프

# %%
tips=sns.load_dataset('tips')
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# - 히스토그램 : 데이터 프레임의 열 데이터 분포와 빈도를 살펴보는 용도
#
#  - 일변량 그래프: 변수 하나만 사용해서 그린 그래프

# %%
fig=plt.figure()
axes1=fig.add_subplot(1,1,1)
# Out:
# <div id='18a4fa8a-4e9f-42b4-add4-f05bd3bf8d77'></div>

# %%
# bins 인잣값으로 x축 간격 조정
axes1.hist(tips['total_bill'],bins=10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')
fig
# Out:
# <div id='442c1d9e-2b2e-4205-bb82-2c1686e8d62c'></div>

# %% [markdown]
# - 산점도 그래프 (이변량 그래프) 변수 2개 이용

# %%
scatter_plot=plt.figure()
axes1=scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'],tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <div id='7b50b6ad-5020-451c-bbe6-6f824187ced6'></div>
# Text(0, 0.5, 'Tip')

# %% [markdown]
# - 박스 그래프 : 이산형 변수와 연속형 변수를 함께 사용하는 그래프

# %%
boxplot=plt.figure()
axes1=boxplot.add_subplot(1,1,1)

axes1.boxplot([tips[tips['sex']=='Female']['tip'],
               tips[tips['sex']=='Male']['tip']],
              labels=['Female','Male'])

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# <div id='4bad3dc4-5d4c-476f-8443-15176a2b2dfe'></div>
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# - 다변량 그래프 그리기 : 3개 이상의 변수 사용한 그래프
#
# - 산점도 그래프

# %%
def recode_sex(sex):
  if sex=='Female':
    return 0
  else:
    return 1

# %%
tips['sex_color']=tips['sex'].apply(recode_sex)

# %%
scatter_plot=plt.figure()
axes1=scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],
    s=tips['size']*10,
    c=tips['sex_color'],
    alpha=0.5)
axes1.set_title('Total Bill vs Tip Colored by SEx and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <div id='7f693517-193d-4d4a-af3e-e3dfde99f06f'></div>
# Text(0, 0.5, 'Tip')

# %% [markdown]
# **<seaborn 라이브러리 자유자재로 사용하기>**
#
# - 단변량 그래프 그리기 - 히스토그램

# %%
import seaborn as sns
tips=sns.load_dataset('tips')

# %%
ax=plt.subplots()
ax=sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# <div id='72eeffbb-b6d7-42ef-a45d-6521427bf510'></div>
# <ipython-input-31-ce4ae7b162d4>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(tips['total_bill'])
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %% [markdown]
# - distplot()을 쓰면 히스토그램과 밀집도 그래프를 같이 그린다.

# %%
#히스토그램만 나타내기
ax=plt.subplots()
ax=sns.displot(tips['total_bill'],kde=False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')

# %%
#밀집도그래프만 나타내기
ax=plt.subplots()
ax=sns.distplot(tips['total_bill'],hist=False)
ax.set_title('Total Bill density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probability')
# Out:
# <div id='09eef4dc-cd63-4090-9a1b-4ff111c9001f'></div>
# <ipython-input-35-05d7c7e8a0df>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(tips['total_bill'],hist=False)
# Text(0, 0.5, 'Unit Probability')

# %%
#rug 인자를 추가하여 양탄자 그래프까지 그리기
ax=plt.subplots()
ax=sns.distplot(tips['total_bill'],rug=True)
ax.set_title('Total Bill histogram with Density and Rug plot')
ax.set_xlabel('Total Bill')
# Out:
# <div id='392c4dec-c6c2-480c-b26b-dc51249af51b'></div>
# <ipython-input-36-d0ce2cb10205>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(tips['total_bill'],rug=True)
# Text(0.5, 0, 'Total Bill')

# %%
#count 그래프 그리기 : 이산값을 나타냄

ax=plt.subplots()
ax=sns.countplot('day',data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')

# %% [markdown]
# <다양한 종류의 이변량 그래프 그리기>
# - seaborn 라이브러리로 산점도 그래프 그리기
#
#  - regplot 메서드 이용
#  - 회귀선 제거하려면 fit_reg=False

# %%
ax=plt.subplots()
ax=sns.regplot(x='total_bill',y='tip',data=tips)
ax.set_title('Scatterplot of total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <div id='ee244435-5856-4c73-98e7-517be3904142'></div>
# Text(0, 0.5, 'Tip')

# %%
ax=plt.subplots()
ax=sns.regplot(x='total_bill',y='tip',data=tips,fit_reg=False)
ax.set_title('Scatterplot of total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <ipython-input-40-5df9c3e251c0>:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   ax=plt.subplots()
# <div id='5654aed8-fa78-45b6-ae1f-c129ffc4d54d'></div>
# Text(0, 0.5, 'Tip')

# %% [markdown]
# - jointplot 메서드

# %%
joint=sns.jointplot(x='total_bill',y='tip',data=tips)
joint.set_axis_labels(xlabel='Total Bill',ylabel='Tip')
joint.fig.suptitle('Joint plot of total bill and tip',fontsize=10,y=1.03)
# Out:
# <div id='3344c761-4a31-4d56-a5c1-f09f9ecac102'></div>
# Text(0.5, 1.03, 'Joint plot of total bill and tip')

# %% [markdown]
# - 육각 그래프 사용하면 산점도 그래프 점 구분 쉬워진다

# %%
hexbin=sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')
hexbin.set_axis_labels(xlabel='Total Bill',ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint plot of Total Bill and Tip',fontsize=10, y=1.03)
# Out:
# <div id='45e893b0-1d1e-4368-94f1-6414e549429e'></div>
# Text(0.5, 1.03, 'Hexbin Joint plot of Total Bill and Tip')

# %% [markdown]
# - 이차원 밀집도 그리기
#  - kdeplot 메서드

# %%
ax=plt.subplots()
ax=sns.kdeplot(data=tips['total_bill'],
               data2=tips['tip'],
               shade=True)
ax.set_tile('Kernel Density plot of total bill and tip')
ax.set_xlabel('Total bill')
ax.set_ylabel('Tip')

# %% [markdown]
# - 바 그래프 그리기
#  - 지정한 변수의 평균을 계산하여 그릴 수 있음

# %%
ax=plt.subplots()
ax=sns.barplot(x='time',y='total_bill',data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# <div id='9965dc8c-5de9-4856-aafe-0ad16c53dd5f'></div>
# Text(0, 0.5, 'Average total bill')

# %% [markdown]
# - 박스 그래프 그리기
#  - 최솟값, 1분위수, 중간값, 3분위수, 최댓값, 이상치 등을 표현

# %%
ax=plt.subplots()
ax=sns.boxplot(x='time',y='total_bill',data=tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# <div id='60b2c59f-bf42-4da0-bc56-ec96e47b7852'></div>
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# - 바이올린 그래프 violinplot

# %%
ax=plt.subplots()
ax=sns.violinplot(x='time',y='total_bill',data=tips)
ax.set_title('Violin plot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# <div id='5223faea-b990-47a3-bb7d-078286ac16c1'></div>
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# - 관계 그래프 그리기 pairplot()
#  - 중복된 정보가 표현된다는 단점

# %%
fig=sns.pairplot(tips)
# Out:
# <div id='956a4c35-f7af-46b5-8bc6-c7ce9bedaddf'></div>

# %%
#map_upper : 대각선 기준 위쪽에 그릴 그래프 지정

pair_grid=sns.PairGrid(tips)
pair_grid=pair_grid.map_upper(sns.regplot)
pair_grid=pair_grip.map_lower(sns.kdeplot)
pair_grid=pair_grid.map_diag(sns.distplot,rug=True)
plt.show()

# %% [markdown]
# **<다변량 그래프 그리기>**
#
# - seaborn 라이브러리로 바이올린 그래프 그리기 - 색상 추가

# %%
ax=plt.subplots()
ax=sns.violinplot(x='time',y='total_bill',hue='sex',data='tips',split=True)

# %% [markdown]
# - 산점도, 관계 그래프 그리기 - 색상 추가

# %%
scatter=sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',fit_reg=False)
# Out:
# <div id='5e8cd644-7275-4e75-babe-88b569e68fdd'></div>

# %%
fig=sns.pairplot(tips,hue='sex')
# Out:
# <div id='4c20e073-0694-458b-af75-1feab685173e'></div>

# %%
# 산점도 그래프의 크기와 모양 조절하기
scatter=sns.lmplot(x='total_bill',y='tip',data=tips,fit_reg=False,hue='sex',scatter_kws={'s':tips['size']*10})

# %%
#산점도 그래프의 점을 다른 기호로 표현하기 - markers인잣값
scatter=sns.lmplot(x='total_bill',y='tip',data=tips,fit_reg=False,hue='sex',markers=['o','x'],scatter_kws={'s':tips['size']*10})

# %%
#lmplot 메서드로 4개의 데이터 그룹에 대한 그래프 한번에 그리기
anscombe_plot=sns.lmplot(x='x',y='y',data=anscombe,fit_reg=False)
# Out:
# <div id='7f44e88c-4c69-4706-b6f2-b69ea70262f0'></div>

# %%
anscombe_plot=sns.lmplot(x='x',y='y',data=anscombe,fit_reg=False,col='dataset',col_wrap=2)
# Out:
# <div id='af9c5e3e-be37-4c60-be49-4ecfd223999f'></div>

# %% [markdown]
# FacetGrid 클래스로도 그룹별 그래프를 그릴 수 있다

# %%
facet=sns.FacetGrid(tips,col='time')
facet.map(sns.distplot,'total_bill',rug=True)
# Out:
# <div id='3f2da0fd-44cf-49a1-a8d3-73540b4be7fc'></div>
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
facet=sns.FacetGrid(tips,col='day',hue='sex')
facet=facet.map(plt.scatter,'total_bill','tip')
facet=facet.add_legend()
# Out:
# <div id='9b8f893a-7b3e-4007-a3d8-c1c2cadd08a8'></div>

# %%
facet=sns.FacetGrid(tips,col='time',row='smoker',hue='sex')
facet.map(plt.scatter,'total_bill','tip')
# Out:
# <div id='325629d6-027a-43d7-a040-3e93db2528bd'></div>

# %% [markdown]
# **<데이터 프레임과 시리즈로 그래프 그리기>**

# %%
ax=plt.subplots()
ax=tips['total_bill'].plot.hist()
# Out:
# <div id='a860f669-cd40-4eda-8798-92f7341395a3'></div>

# %%
#투명도 조절
fig,ax=plt.subplots()
ax=tips[['total_bill','tip']].plot.hist(alpha=0.5,bins=20,ax=ax)
# Out:
# <div id='add73a79-1d13-43b2-9cd1-c076c8350987'></div>

# %%
#밀집도, 산점도, 육각그래프는 각각 kde, scatter,hexbin
ax=plt.subplots()
ax=tips['tip'].plot.kde()
# Out:
# <div id='fa01f995-118b-4c8e-88e4-1e0d60b3c9a1'></div>

# %%
fig,ax=plt.subplots()
ax=tips.plot.scatter(x='total_bill',y='tip',ax=ax)
# Out:
# <div id='d4994a3b-1620-4175-a939-f7e0dae8bcf5'></div>

# %%
fig,ax=plt.subplots()
ax=tips.plot.hexbin(x='total_bill',y='tip',ax=ax)
# Out:
# <div id='26130b91-038b-434a-92af-c20c2f94095e'></div>

# %%
fig,ax=plt.subplots()
ax=tips.plot.hexbin(x='total_bill',y='tip',gridsize=10,ax=ax)
# Out:
# <div id='5719c000-6516-4662-adc4-81f8bb557c5b'></div>

# %%
fig,ax=plt.subplots()
ax=tips.plot.box(ax=ax)
# Out:
# <div id='2870301d-d6c4-4541-986f-7bf78963e5b5'></div>

# %% [markdown]
# **<seaborn 라이브러리로 그래프 스타일 설정하기>**

# %%
fig,ax=plt.subplots()
ax=sns.violinplot(x='time',y='total_bill',hue='sex',data=tips,split=True)
# Out:
# <div id='1ebf9413-9751-46e3-be74-05570ee11ad3'></div>

# %%
#whitegrid로 스타일 설정
sns.set_style('whitegrid')
fig,ax=plt.subplots()
ax=sns.violinplot(x='time',y='total_bill',hue='sex',data=tips,split=True)
# Out:
# <div id='47ae4248-e340-491a-a9a6-311ab2b65b86'></div>

# %%
fig=plt.figure()
seaborn_styles=['darkgrid','whitegrid','dark','white','ticks']

for idx, style in enumerate(seaborn_styles):
  plot_position=idx+1
  with sns.axes_style(style):
    ax=fig.add_subplot(2,3,plot_position)
    violin=sns.violinplot(x='time',y='total_bill',data=tips,ax=ax)
    violin.set_title(style)

fig.tight_layout()
# Out:
# <div id='c72f3af8-c932-45e2-9772-1f9dbdf8743b'></div>
